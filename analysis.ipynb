# %%
import pandas as pd
import numpy as np

# %%
# !pip install pubchempy
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pubchempy: filename=PubChemPy-1.0.4-py3-none-any.whl size=13840 sha256=56e26e3d64ef75c70c50df40c030a080971468e97b56d261eb569e4bb51c43ea
#   Stored in directory: c:\users\panth\appdata\local\pip\cache\wheels\78\0f\d0\080f82ce0d7fdc771401b6acac304bd2ee77d67dee34737bd6
# Successfully built pubchempy
# ...

# %%
import pubchempy as pcp

# Fetch data for a single substance using its name
substance_name = 'aspirin'
compound = pcp.get_compounds(substance_name, 'name')[0]
compound.to_dict()
# Out:
# {'atom_stereo_count': 0,
#  'atoms': [{'aid': 1, 'number': 8, 'element': 'O', 'x': 3.732, 'y': -0.06},
#   {'aid': 2, 'number': 8, 'element': 'O', 'x': 6.3301, 'y': 1.44},
#   {'aid': 3, 'number': 8, 'element': 'O', 'x': 4.5981, 'y': 1.44},
#   {'aid': 4, 'number': 8, 'element': 'O', 'x': 2.866, 'y': -1.56},
#   {'aid': 5, 'number': 6, 'element': 'C', 'x': 4.5981, 'y': -0.56},
#   {'aid': 6, 'number': 6, 'element': 'C', 'x': 5.4641, 'y': -0.06},
#   {'aid': 7, 'number': 6, 'element': 'C', 'x': 4.5981, 'y': -1.56},
#   {'aid': 8, 'number': 6, 'element': 'C', 'x': 6.3301, 'y': -0.56},
#   {'aid': 9, 'number': 6, 'element': 'C', 'x': 5.4641, 'y': -2.06},
#   {'aid': 10, 'number': 6, 'element': 'C', 'x': 6.3301, 'y': -1.56},
#   {'aid': 11, 'number': 6, 'element': 'C', 'x': 5.4641, 'y': 0.94},
#   {'aid': 12, 'number': 6, 'element': 'C', 'x': 2.866, 'y': -0.56},
#   {'aid': 13, 'number': 6, 'element': 'C', 'x': 2, 'y': -0.06},
# ...

# %%
# !pip install smartsheet-python-sdk

# %%
df = pd.read_stata('full_analysis.dta')
#df.head()

# %%
#sort by sampleid
pd.set_option('display.max_columns', None)

df_sorted = df.sort_values(by='sampleid')
df_sorted


# state
# location (city)
# Out:
#           sampleid  counter sampletype expectedsubstance              program  \
# 0         06082021        3    unknown            heroin  NC Survivor's Union
# 10225     06082021        3    unknown            heroin  NC Survivor's Union
# 10227       111422      493    spatula   methamphetamine
# 10226       111422      493    spatula   methamphetamine
# 1           111422      493    spatula   methamphetamine
# ...            ...      ...        ...               ...                  ...
# 10223       USU213      264    spatula           unknown  NC Survivor's Union
# 37754       USU213      264    spatula           unknown  NC Survivor's Union
# 10224  USUDMT32221        1    unknown               DMT  NC Survivor's Union
# 37758  USUDMT32221        1    unknown               DMT  NC Survivor's Union
# 37759  USUDMT32221        1    unknown               DMT  NC Survivor's Union
#
#              date  color                texture sensations texture_notes  \
# 0        6/8/2021
# ...

# %%
#get the unique rows for each subtance
first_instances = df_sorted.drop_duplicates(subset=['sampleid'], keep='first')
first_instances
# Out:
#                sampleid  counter sampletype expectedsubstance  \
# 0              06082021        3    unknown            heroin
# 10227            111422      493    spatula   methamphetamine
# 2               200001A       74    spatula            heroin
# 10231            200028       67    spatula            heroin
# 4                200031       64    spatula            heroin
# ...                 ...      ...        ...               ...
# 37738  USU05052021_1422        2    unknown             crack
# 37743            USU201      266    spatula  heroin; fentanyl
# 37752            USU207      265    spatula           unknown
# 37756            USU213      264    spatula           unknown
# 10224       USUDMT32221        1    unknown               DMT
#
#                    program        date        color                texture  \
# 0      NC Survivor's Union    6/8/2021
# 10227                       10/19/2022        white  powder; chunky; flaky
# ...

# %%
overdose = first_instances[['overdose']]
overdose.value_counts()
# Out:
# overdose
# not overdose related             6329
# unknown                          3151
# involved in OD                    734
#                                     4
# not overdose related; unknown       4
# involved in OD; unknown             1
# u                                   1
# unknown; not overdose related       1
# Name: count, dtype: int64

# %%
overdose['overdose'] = np.where(overdose['overdose'] == 'involved in OD', 1, 0)
overdose
# Out:
# C:\Users\panth\AppData\Local\Temp\ipykernel_30072\1427426713.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overdose['overdose'] = np.where(overdose['overdose'] == 'involved in OD', 1, 0)
#        overdose
# 0             0
# 10227         0
# 2             0
# 10231         0
# 4             0
# ...         ...
# 37738         0
# 37743         0
# 37752         0
# 37756         0
# 10224         0
#
# [10225 rows x 1 columns]
